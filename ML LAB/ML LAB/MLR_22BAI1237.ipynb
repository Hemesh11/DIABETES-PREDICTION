# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

#importing dataset using panda
dataset = pd.read_csv('kc_house_data.csv')
#to see what my dataset is comprised of
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
print(dataset.dtypes)
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
print(dataset.isnull().any())
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
#dropping the id and date column
dataset = dataset.drop(['id','date'], axis = 1)
print(dataset.dtypes)
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#understanding the distribution with seaborn
with sns.plotting_context("notebook",font_scale=2.5):
    g = sns.pairplot(dataset[['sqft_lot','sqft_above','price','sqft_living','bedrooms']], 
                 hue='bedrooms', palette='tab20',height=6)
g.set(xticklabels=[]);
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
#separating independent and dependent variable
X = dataset.iloc[:,1:].values
Y = dataset.iloc[:,0].values
#splitting dataset into training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)

# Predicting the Test set results
Y_pred = regressor.predict(X_test)

# %%
print(Y_pred)
# Out:
# [ 386540.99847822 1516969.01534105  538662.72575248 ...  526000.75505745
#   313924.63663311  400525.67314568]

# %%
#another data set

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

#importing dataset using panda
dataset = pd.read_csv('Student.csv')
#to see what my dataset is comprised of
dataset.head()
# Out:
#    Hours_Studied  Previous_Scores Extra_Activities  Sleep_Hours  \
# 0              7               99              Yes            9
# 1              4               82               No            4
# 2              8               51              Yes            7
# 3              5               52              Yes            5
# 4              7               75               No            8
#
#    Papers_Practiced  Performance_Index
# 0                 1                 91
# 1                 2                 65
# 2                 2                 45
# 3                 2                 36
# 4                 5                 66

# %%
print(dataset.dtypes)
# Out:
# Hours_Studied         int64
# Previous_Scores       int64
# Extra_Activities     object
# Sleep_Hours           int64
# Papers_Practiced      int64
# Performance_Index     int64
# dtype: object

# %%
print(dataset.isnull().any())
# Out:
# Hours_Studied        False
# Previous_Scores      False
# Extra_Activities     False
# Sleep_Hours          False
# Papers_Practiced     False
# Performance_Index    False
# dtype: bool

# %%
with sns.plotting_context("notebook",font_scale=2.5):
    g = sns.pairplot(dataset[['Hours_Studied','Previous_Scores','Sleep_Hours','Performance_Index']]
                     ,  palette='tab20',size=6)
g.set(xticklabels=[]);
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
dataset['Extra_Activities'] = dataset['Extra_Activities'].map({'Yes':1, 'No':0})

# %%
#separating independent and dependent variable
X = dataset.iloc[:,1:].values
y = dataset.iloc[:,0].values
#splitting dataset into training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,test_size=0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [4.89693932 6.77463746 6.48891234 ... 3.16345309 4.95023824 5.41012515]

# %%
corr_matrix=dataset.corr()
print(corr_matrix)
# Out:
#                    Hours_Studied  Previous_Scores  Extra_Activities  \
# Hours_Studied           1.000000        -0.012390          0.003873
# Previous_Scores        -0.012390         1.000000          0.008369
# Extra_Activities        0.003873         0.008369          1.000000
# Sleep_Hours             0.001245         0.005944         -0.023284
# Papers_Practiced        0.017463         0.007888          0.013103
# Performance_Index       0.373730         0.915189          0.024525
#
#                    Sleep_Hours  Papers_Practiced  Performance_Index
# Hours_Studied         0.001245          0.017463           0.373730
# Previous_Scores       0.005944          0.007888           0.915189
# Extra_Activities     -0.023284          0.013103           0.024525
# Sleep_Hours           1.000000          0.003990           0.048106
# Papers_Practiced      0.003990          1.000000           0.043268
# Performance_Index     0.048106          0.043268           1.000000

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data=pd.read_csv('Student.csv')
print(data.head())
# Out:
#    Hours_Studied  Previous_Scores Extra_Activities  Sleep_Hours  \
# 0              7               99              Yes            9
# 1              4               82               No            4
# 2              8               51              Yes            7
# 3              5               52              Yes            5
# 4              7               75               No            8
#
#    Papers_Practiced  Performance_Index
# 0                 1                 91
# 1                 2                 65
# 2                 2                 45
# 3                 2                 36
# 4                 5                 66

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

data['Extra_Activities'] = data['Extra_Activities'].map({'Yes':1, 'No':0}) 
  
# the independent variables set 
X = data[['Hours_Studied', 'Previous_Scores', 'Extra_Activities','Sleep_Hours','Papers_Practiced']] 
  
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
#             feature        VIF
# 0     Hours_Studied   4.263244
# 1   Previous_Scores  10.088586
# 2  Extra_Activities   1.928235
# 3       Sleep_Hours   9.833594
# 4  Papers_Practiced   3.350481

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

formula = 'Performance_Index ~ Hours_Studied + Previous_Scores + Extra_Activities+ Sleep_Hours + Papers_Practiced'
model = ols(formula, data=data).fit()
anova_table = sm.stats.anova_lm(model)
print(anova_table)
# Out:
#                       df        sum_sq       mean_sq              F  \
# Hours_Studied        1.0  5.155178e+05  5.155178e+05  124106.237045
# Previous_Scores      1.0  3.123194e+06  3.123194e+06  751880.619879
# Extra_Activities     1.0  8.679193e+02  8.679193e+02     208.943703
# Sleep_Hours          1.0  6.675426e+03  6.675426e+03    1607.048344
# Papers_Practiced     1.0  3.085977e+03  3.085977e+03     742.920869
# Residual          9994.0  4.151351e+04  4.153843e+00            NaN
#
#                          PR(>F)
# Hours_Studied      0.000000e+00
# Previous_Scores    0.000000e+00
# Extra_Activities   6.927653e-47
# Sleep_Hours        0.000000e+00
# Papers_Practiced  7.461573e-158
# Residual                    NaN

# %%
anova_results = sm.stats.anova_lm(model)

f_statistic = [anova_results['F'][i] for i in range(5)]
p_value = [anova_results['PR(>F)'][i] for i in range(5)]

print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
# Out:
# F-statistic: [124106.23704466988, 751880.6198792554, 208.94370254343795, 1607.0483438036683, 742.920869406753]
# p-value: [0.0, 0.0, 6.927653470595433e-47, 0.0, 7.461573308186304e-158]
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_14772\4025960296.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_statistic = [anova_results['F'][i] for i in range(5)]
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_14772\4025960296.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = [anova_results['PR(>F)'][i] for i in range(5)]

# %%
#hyothetical Testing 
hyp_test=False
count=0
for i in range(5):
    if p_value[i] < 0.05 :
        count+=1
if(count==5):
    hyp_test=True
if(hyp_test):
    print("We reject the null hypothesis H0")
    print("All 5 parameters are significant for Performance Index")
else:
    print("We fail to reject the null hypothesis H0")
# Out:
# We reject the null hypothesis H0
# All 5 parameters are significant for Performance Index

# %%
#R^2 and Adjusted R^2
formula = 'Performance_Index ~ Hours_Studied + Previous_Scores + Extra_Activities+ Sleep_Hours + Papers_Practiced'
model = ols(formula, data=data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Performance_Index   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                 1.757e+05
# Date:                Mon, 04 Mar 2024   Prob (F-statistic):               0.00
# Time:                        08:36:41   Log-Likelihood:                -21307.
# No. Observations:               10000   AIC:                         4.263e+04
# Df Residuals:                    9994   BIC:                         4.267e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
num_coeff = len(model.params)
for i in range(num_coeff):
    coef_values = [1 if j == i else 0 for j in range(num_coeff)]
    t_test_result = model.t_test(coef_values)
    
    print(f"T-Test for coefficient {i}:")
    print(t_test_result)
    print("\n")
# Out:
# T-Test for coefficient 0:
#                              Test for Constraints
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0           -34.0756      0.127   -268.010      0.000     -34.325     -33.826
# ...
#
#
# T-Test for coefficient 1:
#                              Test for Constraints
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             2.8530      0.008    362.353      0.000       2.838       2.868
# ...
#
#
# T-Test for coefficient 2:
#                              Test for Constraints
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             1.0184      0.001    866.450      0.000       1.016       1.021
# ...
#
#
# ...
