# %% [markdown]
# **1. Importing Libraries like Numpy, Pandas , Matplotlib , Seaborn and Sklearn**

# %%
#numpy
import numpy as np

#pandas
import pandas as pd

#Seaborn
import seaborn as sns

#Matplotlib
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2. LOAD THE DATA SET**

# %%
#load pima indians diabetes dataset

# %%
df=pd.read_csv("/kaggle/input/pima-indians-diabetes-database/diabetes.csv")

# %% [markdown]
# ***3.Exploratory Data Analysis*** <br>
# **3.1 Understanding variables** <br>
# *      a. Head of the dataset

# %%
df.head()

# %%
df.tail()

# %%
df.sample(10)

# %% [markdown]
# * b. Shape of the dataset

# %%
df.shape

# %% [markdown]
# * c. List type of all coloumns

# %%
df.dtypes

# %% [markdown]
# * d. info of the dataset

# %%
df.info()

# %% [markdown]
# * e. summary of dataset

# %%
#statistical summary
df.describe()

# %% [markdown]
# **3.2 DATA CLEANING**
# * a. drop the duplicates

# %%
df.shape

# %%
df=df.drop_duplicates()
df.shape

# %% [markdown]
# * b. check the null values

# %%
#count of null values
#check the missing values in any coloumn
#display number of null values in every coloumn in dataset
df.isnull().sum()

# %% [markdown]
# there is no null value in the dataset

# %%
df.columns

# %% [markdown]
# **Check the number of zero values in dataset**

# %%
print('No. of zero values in Glucose', df[df['Glucose']==0].shape[0])
print('No. of zero values in BloodPressure', df[df['BloodPressure']==0].shape[0])
print('No. of zero values in SkinThickness', df[df['SkinThickness']==0].shape[0])
print('No. of zero values in Insulin', df[df['Insulin']==0].shape[0])
print('No. of zero values in BMI', df[df['BMI']==0].shape[0])

# %% [markdown]
# **Replace the no. of zeroes with mean of that columns**

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

# %%
print('No. of zero values in Glucose', df[df['Glucose']==0].shape[0])
print('No. of zero values in BloodPressure', df[df['BloodPressure']==0].shape[0])
print('No. of zero values in SkinThickness', df[df['SkinThickness']==0].shape[0])
print('No. of zero values in Insulin', df[df['Insulin']==0].shape[0])
print('No. of zero values in BMI', df[df['BMI']==0].shape[0])

# %%
df.describe()

# %% [markdown]
# **4. Data Visualization**<br>**4.1 Count plot**

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the Pima Indians Diabetes dataset

plt.figure(figsize=(6, 6))
df['Outcome'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', shadow=True)
plt.title('Outcome')
plt.ylabel('')
N, P = df['Outcome'].value_counts()
print('Negative (0):', N)
print('Positive (1):', P)
plt.show()

# %% [markdown]
# **4.2 HISTOGRAMS**

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# **4.3 SCATTER PLOT**

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(20,20))
plt.show()

# %% [markdown]
# **4.4 PAIRPLOT**

# %%
sns.pairplot(data=df,hue='Outcome')
plt.show()

# %% [markdown]
# **4.5 ANALYZING RELATIONSHIP BETWEEN THE VARIABLES**<BR>  **CORRELATION ANALYSIS**

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# **5) Split the data into X and y**

# %%
target_name = 'Outcome'
#separate object for target feature
y=df[target_name]
#seaparate object for input features
X=df.drop(target_name,axis=1)

# %%
X.head()

# %%
y.head()

# %% [markdown]
# **6)Apply feature scaling**

# %%
#standard scalar
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(X)
SSX = scaler.transform(X)

# %% [markdown]
# **7) TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

# %%
X_train.shape, y_train.shape

# %%
X_test.shape , y_test.shape

# %% [markdown]
# **8) BUILD THE CLASSIFICATION ALGORITHM**<br>
# **8.1) LOGISTIC REGRESSION<br>8.2)KNN CLASSIFIER<BR>8.3)NAIVE-BAYES CLASSIFIER
# <BR>8.4)SUPPORT VECTOR MACHINE
# <BR>8.5)DECISION TREE<BR>8.6) RANDOM FOREST**

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(X_train,y_train)

# %%
X_test.shape

# %%
lr_pred=lr.predict(X_test)

# %%
lr_pred.shape

# %%
#Train score & Test score of Logistic Regression
from sklearn.metrics import acuracy_score
print("Train Accuracy of Logistic Regression", lr.score(X_train,y_train)*100)
print("Accuracy (Test) score of Logistic Regression", lr.score(X_tes,y_test)*100)
print("Accuracy (Test) score of Logistic Regression", accuracy_score(y_tes,lr_pred)*100)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

# %%
knn_pred=knn.predict(X_test)

# %%
knn_pred.shape

# %%
#Train score & Test score of KNN
print("Train Accuracy of KNN", knn.score(X_train,y_train)*100)
print("Accuracy (Test) score of KNN", knn.score(X_tes,y_test)*100)
print("Accuracy (Test) score of KNN", accuracy_score(y_tes,knn_pred)*100)

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,y_train)

# %%
nb_pred=nb.predict(X_test)

# %%
nb_pred.shape

# %%
#Train score & Test score of Naive Bayes
print("Train Accuracy of Naive Bayes", nb.score(X_train,y_train)*100)
print("Accuracy (Test) score of Naive Bayes", nb.score(X_tes,y_test)*100)
print("Accuracy (Test) score of Naive Bayes", accuracy_score(y_tes,nb_pred)*100)

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(X_train,y_train)

# %%
sv_pred=sv.predict(X_test)

# %%
sv_pred.shape

# %%
#Train score & Test score of SVM
print("Train Accuracy of SVM", sv.score(X_train,y_train)*100)
print("Accuracy (Test) score of SVM", sv.score(X_tes,y_test)*100)
print("Accuracy (Test) score of SVM", accuracy_score(y_tes,sv_pred)*100)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)

# %%
dt_pred=dt.predict(X_test)

# %%
dt_pred.shape

# %%
#Train score & Test score of Decision Tree
print("Train Accuracy of Decision Tree", dt.score(X_train,y_train)*100)
print("Accuracy (Test) score of Decision Tree", dt.score(X_tes,y_test)*100)
print("Accuracy (Test) score of Decision Tree", accuracy_score(y_tes,dt_pred)*100)

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(criterion='entropy')
rf.fit(X_train,y_train)

# %%
rf_pred=rf.predict(X_test)

# %%
rf_pred.shape

# %%
#Train score & Test score of Random Forest
print("Train Accuracy of Random Forest", rf.score(X_train,y_train)*100)
print("Accuracy (Test) score of Random Forest", rf.score(X_tes,y_test)*100)
print("Accuracy (Test) score of Random Forest", accuracy_score(y_tes,rf_pred)*100)

# %% [markdown]
# **9) MAKING PREDICTION**
